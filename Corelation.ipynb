# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("correlation.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight  Item_MRP  Item_Outlet_Sales
# 0              FDA15        9.300  249.8092          3735.1380
# 1              DRC01        5.920   48.2692           443.4228
# 2              FDN15       17.500  141.6180          2097.2700
# 3              FDX07       19.200  182.0950           732.3800
# 4              NCD19        8.930   53.8614           994.7052
# ...              ...          ...       ...                ...
# 8518           FDF22        6.865  214.5218          2778.3834
# 8519           FDS36        8.380  108.1570           549.2850
# 8520           NCJ29       10.600   85.1224          1193.1136
# 8521           FDN46        7.210  103.1332          1845.5976
# 8522           DRG01       14.800   75.4670           765.6700
#
# [8523 rows x 4 columns]

# %%
#Correlation between Item_Weight and Item_MRP
data[['Item_Weight','Item_MRP']].corr()
#single squared in python used for accessing data in list, where double squared is used for accessing data in matrix.
# Out:
#              Item_Weight  Item_MRP
# Item_Weight     1.000000  0.027141
# Item_MRP        0.027141  1.000000

# %%
data[['Item_MRP','Item_Outlet_Sales']].corr()
# Out:
#                    Item_MRP  Item_Outlet_Sales
# Item_MRP           1.000000           0.567574
# Item_Outlet_Sales  0.567574           1.000000

# %%
data[['Item_Weight','Item_Outlet_Sales']].corr()
# Out:
#                    Item_Weight  Item_Outlet_Sales
# Item_Weight           1.000000           0.014123
# Item_Outlet_Sales     0.014123           1.000000

# %%
cor = data.corr() #Calcs the value of correlation matrix
# Corelation matrix is a square matrix that contains the correlation coefficients between each pair of variables in DF
plt.figure(figsize=(16,10))
sns.heatmap(cor)
"""
-1: Perfect negative correlation
0: No correlation
1: Perfect positive correlation

-> Heatmap is a graphical representation of matrix where values are in colors.
-> Colored according to the Strength
-> Seaborn library is used for visualization
-> Red indicates a strong positive, blue indicates strong negative.
"""
# Out:
# <ipython-input-18-3babd5d256e3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = data.corr() #Calcs the value of correlation matrix
# '\n-1: Perfect negative correlation\n0: No correlation\n1: Perfect positive correlation\n'

# %%
data.corr()
# Out:
# <ipython-input-19-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Item_Weight  Item_MRP  Item_Outlet_Sales
# Item_Weight           1.000000  0.027141           0.014123
# Item_MRP              0.027141  1.000000           0.567574
# Item_Outlet_Sales     0.014123  0.567574           1.000000
