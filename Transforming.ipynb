# %%
#Transforming variables datasets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
np.power(data['Age'],1/3).plot.hist()
"""The above means raising each element to the power of 1/3 applies the np.power func to each element in column.
This basically creates new array
np.power is a mathematical function for performing transformation
"""
# Out:
# <Axes: ylabel='Frequency'>

# %%
bins=[0,19,80]

group=['children', 'Adult']
"""
Bins: Values are representing the boundaries of different age groups
group: It basically represent the labels for age groups defined by bins """
# Out:
# '\nBins: Values are representing the boundaries of different age groups\ngroup: It basically represent the labels for age groups defined by bins '

# %%
df['type']=pd.cut(data['Age'],bins)
""" pd.cut basically used for categorizing the values in age group.
here df['type'] creates a new column which basically named by type.
 """
# Out:
# " pd.cut basically used for categorizing the values in age group. \nhere df['type'] creates a new column which basically named by type.\n "

# %%
df['type'].value_counts()
# Out:
# (19, 80]    550
# (0, 19]     164
# Name: type, dtype: int64

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
