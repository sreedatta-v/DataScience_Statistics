# %%
#Importing the required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt #For Graph plotting

read_data = pd.read_csv('Median.csv') #Reading the csv file

# %%
read_data.head()
# Out:
#    Student  Overall Marks Gender    Subject
# 0    Anish           9700   Male    English
# 1  Rishabh             83   Male    English
# 2     Ajay             78   Male    Physics
# 3  Abhinav             86   Male  Chemistry
# 4   Anurag             91   Male    English
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Overall Marks'].plot(kind='hist', bins=20, title='Overall Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Student').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
median_data = read_data['Overall Marks'].median() #Calculating the median of the providede dataset

# %%
print(median_data) #Printing the median
# Out:
# 77.0

# %%
#Performing Quartiles

Q1 = read_data['Overall Marks'].quantile(0.25)
print(Q1)
# Out:
# 57.25

# %%
Q2 = read_data['Overall Marks'].quantile(0.50)
print(Q2)
# Out:
# 77.0

# %%
Q3 = read_data['Overall Marks'].quantile(0.75)
print(Q3)
# Out:
# 87.25

# %%
average = Q1 + Q2 + Q3/3
print(average)
# Out:
# 163.33333333333334
